# %%
import pandas as pd
import nltk
import re

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/morganedaniel/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
bdd_sbt_df = pd.read_csv("/Users/morganedaniel/Downloads/BDD_SBT_from_excel.csv")

# %%
bdd_sbt_df.head()
# Out:
#                      Company Name          ISIN Near term - Target Status  \
# 0  Hongkong Land Holdings Limited  BMG4587L1090                 Committed
# 1                   Iress Limited           NaN                 Committed
# 2                  Jacuzzi Brands           NaN                 Committed
# 3                     Klimasan AŞ           NaN                 Committed
# 4                            Mavi  TREMAVI00037                 Committed
#
#   Near term - Target Classification Near term - Target Year  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
#
#   Long term - Target Status Long term - Target Classification  \
# 0                       NaN                               NaN
# ...

# %%
food_companies_df = bdd_sbt_df[bdd_sbt_df['Sector']=='Food and Beverage Processing']

# %%
food_companies_with_target_df = food_companies_df[food_companies_df['Target'].notna()]

# %%
len(food_companies_with_target_df)
# Out:
# 101

# %%
text_to_analyze = food_companies_with_target_df['Target'].iloc[0]
text_to_analyze
# Out:
# 'This target was approved using a streamlined target validation route exclusive to small and medium-sized enterprises (SMEs). https://sciencebasedtargets.org/faqs-for-smes/ Cafédirect plc commits to reduce scope 1 and scope 2 GHG emissions 46% by 2030 from a 2019 base year, and to measure and reduce its scope 3 emissions.'

# %%
# Preprocessing
sentences = nltk.sent_tokenize(text_to_analyze)
sentences = [nltk.word_tokenize(sent) for sent in sentences]

#Remove sentences with no word "Scope" in it
sentences_scope = []
for sentence in sentences:
    lower_sentence = [word.lower() for word in sentence]
    if 'scope' in lower_sentence:
        sentences_scope.append(sentence)
sentences_scope = [nltk.pos_tag(sent) for sent in sentences_scope]

# %%
grammar =""" OBJ: {<NN.*>+<CD><NN><IN><CD>} """
cp = nltk.RegexpParser(grammar)
cp.parse(sentences_scope[0])
# Out:
# Tree('S', [('https', 'NN'), (':', ':'), ('//sciencebasedtargets.org/faqs-for-smes/', 'JJ'), ('Cafédirect', 'NNP'), ('plc', 'NN'), ('commits', 'NNS'), ('to', 'TO'), ('reduce', 'VB'), ('scope', 'NN'), ('1', 'CD'), ('and', 'CC'), ('scope', 'VB'), ('2', 'CD'), Tree('OBJ', [('GHG', 'NNP'), ('emissions', 'NNS'), ('46', 'CD'), ('%', 'NN'), ('by', 'IN'), ('2030', 'CD')]), ('from', 'IN'), ('a', 'DT'), ('2019', 'CD'), ('base', 'NN'), ('year', 'NN'), (',', ','), ('and', 'CC'), ('to', 'TO'), ('measure', 'VB'), ('and', 'CC'), ('reduce', 'VB'), ('its', 'PRP$'), ('scope', 'NN'), ('3', 'CD'), ('emissions', 'NNS'), ('.', '.')])

# %%
bdd_sbt_df["reduction_percentage_1"] = np.nan
bdd_sbt_df["reduction_percentage_2"] = np.nan
bdd_sbt_df["reduction_percentage_3"] = np.nan
bdd_sbt_df["target_year_1"] = np.nan
bdd_sbt_df["target_year_2"] = np.nan
bdd_sbt_df["target_year_3"] = np.nan
bdd_sbt_df["base_year_1"] = np.nan
bdd_sbt_df["base_year_2"] = np.nan
bdd_sbt_df["base_year_3"] = np.nan
bdd_sbt_df["perimeter_1"] = np.nan
bdd_sbt_df["perimeter_2"] = np.nan
bdd_sbt_df["perimeter_3"] = np.nan

# %%
def refine_perimeter(perimeter_group):
    reg = r'([0-9]+.?[0-9]+?\ ?%) by ([0-9]+).*and'
    sub_group = re.search(reg, perimeter_group)
    if sub_group:
        return {"reduction_percentage": sub_group.groups()[0], "target_year": sub_group.groups()[1], "perimeter": re.sub(reg, "", perimeter_group) }

# %%
from itertools import groupby

def which_scopes(scope_str):
    scope_tags = nltk.pos_tag(nltk.word_tokenize(scope_str))
    grammar =""" SCOPES: {<JJ>?<NN><CD><CC><VB>?<CD>}
                         {<JJ>?<NN><CD>}
            """
    cp = nltk.RegexpParser(grammar)
    result = cp.parse(scope_tags)
    if len(result) > 1:
        return
    for subtree in result.subtrees():
        if subtree.label() == 'SCOPES': 
            scopes = [token for token, tag in subtree.leaves() if tag == 'CD']
            return scopes

# %%
count = 0
for index, target in  companies_with_target_df['Target'].iteritems():
    print(target)
    sentences = nltk.sent_tokenize(target)
    for sentence in sentences:
        results = re.findall(pattern, sentence)
        if not results:
            continue
        for result in results:
            results_groups = re.search(r'reduce (.*)(scope [0-9].*) (GHG emissions.*) ([0-9]+.?[0-9]+?\ ?%) by ([0-9]+) from a ([0-9]+) base year', result)
            if not results_groups:
                print(f"Clean Data at index {index},: {result}")
                continue
            reduction_percentage = [results_groups.groups()[3]]
            target_year = [results_groups.groups()[4]]
            base_year = [results_groups.groups()[5]]
            perimeter_group = results_groups.groups()[2]
    
            new_perimeter = refine_perimeter(perimeter_group)
            if perimeter_group == "GHG emissions" or not new_perimeter:
                perimeter = perimeter_group
            else:
                target_year.insert(0, new_perimeter["target_year"])
                reduction_percentage.insert(0, new_perimeter["reduction_percentage"])
                perimeter = new_perimeter["perimeter"]
            scopes = which_scopes(" ".join([results_groups.groups()[0], results_groups.groups()[1]]))
            if not scopes:
                continue
            for scope in scopes:
                print(f"reduction_percentage_{scope}: {reduction_percentage}, target_year_{scope}: {target_year}, base_year_{scope}: {base_year}, perimeter_{scope}: {perimeter}")
            #print(scopes, reduction_percentage, target_year, base_year, perimeter)
# Out:
# This target was approved using a streamlined target validation route exclusive to small and medium-sized enterprises (SMEs). https://sciencebasedtargets.org/faqs-for-smes/ (ACIP) Alexandria Company for Industrial Packages commits to reduce scope 1 and scope 2 GHG emissions 25% by 2030 from a 2020 base year, and to measure and reduce its scope 3 emissions.
# reduction_percentage_1: ['25%'], target_year_1: ['2030'], base_year_1: ['2020'], perimeter_1: GHG emissions
# reduction_percentage_2: ['25%'], target_year_2: ['2030'], base_year_2: ['2020'], perimeter_2: GHG emissions
# This target was approved using a streamlined target validation route exclusive to small and medium-sized enterprises (SMEs). https://sciencebasedtargets.org/faqs-for-smes/ AM Værktøj Odense A/S commits to reduce scope 1 and scope 2 GHG emissions 50% by 2030 from a 2018 base year, and to measure and reduce its scope 3 emissions.
# ...

# %%
companies_with_target_df = bdd_sbt_df[bdd_sbt_df['Target'].notna()]

# %%
len(companies_with_target_df)
# Out:
# 1239
