# %%
import pandas as pd

df = pd.read_excel("../data/BDD Surcouche pour dataviz_v03.xlsx")#, dtype={'Groupe': str})
df = df.drop([0])

t1b4_data = df.rename(columns={'Group':'company_name'})#.astype(str)

# %%
# Generating company_id variable

import base64
def encode(text):
  btext = text.encode('utf-8')[:6]
  return base64.b64encode(btext).decode("utf-8") 


t1b4_data['company_id'] = [encode(x) for x in t1b4_data['company_name']]

# %%
# Company selection

company = 'Danone'
index = secteur = t1b4_data[t1b4_data['company_name'] == company].index[0]
secteur = t1b4_data.loc[index, 'Sector']

# %%
t1b4_data
# Out:
#                         company_name            Sector  Logo  Unnamed: 3  \
# 1   Associated British Foods (alim.)              Food   NaN         NaN
# 2                                Bel              Food   NaN         NaN
# 3                             Danone              Food   NaN         NaN
# 4                            Ecotone              Food   NaN         NaN
# 5                            Ferrero              Food   NaN         NaN
# 6                      General Mills              Food   NaN         NaN
# 7                               Hero              Food   NaN         NaN
# 8                            Kellogg              Food   NaN         NaN
# 9                               Mars              Food   NaN         NaN
# 10                          Mondelez              Food   NaN         NaN
# 11                            Nestlé              Food   NaN         NaN
# 12                           Pepsico              Food   NaN         NaN
# 13                            Henkel    Consumer goods   NaN         NaN
# 14                               P&G    Consumer goods   NaN         NaN
# 15                          Unilever    Consumer goods   NaN         NaN
# 16                 Colgate-Palmolive    Consumer goods   NaN         NaN
# 17                              Coty  Hygiene & Beauty   NaN         NaN
# 18                           L'Oréal  Hygiene & Beauty   NaN         NaN
# 19                          Shiseido  Hygiene & Beauty   NaN         NaN
# 20                        Beiersdorf    Consumer goods   NaN         NaN
# 21                     S. C. Johnson    Consumer goods   NaN         NaN
# 22                           Reckitt    Consumer goods   NaN         NaN
# 23                               GSK            Pharma   NaN         NaN
# 24                 Johnson & Johnson            Pharma   NaN         NaN
#
#     Country flag                                  Turnover  Top brand 1  \
# 1            NaN  4 Mrd € (2020) (groupe complet 16 Mrd €)          NaN
# 2            NaN                          3,5 Mrd € (2020)          NaN
# 3            NaN                           25 Mrd € (2019)          NaN
# 4            NaN                          650 Mio € (2019)          NaN
# 5            NaN                           11 Mrd € (2019)          NaN
# 6            NaN                           15 Mrd € (2020)          NaN
# 7            NaN                            1 Mrd € (2020)          NaN
# 8            NaN                           11 Mrd € (2019)          NaN
# 9            NaN                           32 Mrd € (2020)          NaN
# 10           NaN                           22 Mrd € (2020)          NaN
# 11           NaN                           85 Mrd € (2019)          NaN
# 12           NaN                           53 Mrd € (2018)          NaN
# 13           NaN                           19 Mrd € (2020)          NaN
# 14           NaN                           60 Mrd € (2020)          NaN
# 15           NaN                           51 Mrd € (2020)          NaN
# 16           NaN                           15 Mrd € (2020)          NaN
# 17           NaN                            4 Mrd € (2020)          NaN
# 18           NaN                           28 Mrd € (2020)          NaN
# 19           NaN                            7 Mrd € (2020)          NaN
# 20           NaN                            7 Mrd € (2020)          NaN
# 21           NaN                            9 Mrd € (2020)          NaN
# 22           NaN                           16 Mrd € (2020)          NaN
# 23           NaN                           40 Mrd € (2020)          NaN
# 24           NaN                           70 Mrd € (2020)          NaN
#
#     Top brand 2  Top brand 3  Top brand 4  ...             Cat 5 name  \
# 1           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 2           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 3           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 4           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 5           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 6           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 7           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 8           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 9           NaN          NaN          NaN  ...  Sc.3 - Use of product
# 10          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 11          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 12          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 13          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 14          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 15          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 16          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 17          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 18          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 19          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 20          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 21          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 22          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 23          NaN          NaN          NaN  ...  Sc.3 - Use of product
# 24          NaN          NaN          NaN  ...  Sc.3 - Use of product
#
#     Cat 6 amount  Cat 6 name  Wording interactive 1  Wording interactive 2  \
# 1           0.05      Others                    NaN                    NaN
# 2           0.05      Others                    NaN                    NaN
# 3           0.05      Others                    NaN                    NaN
# 4           0.05      Others                    NaN                    NaN
# 5           0.05      Others                    NaN                    NaN
# 6           0.05      Others                    NaN                    NaN
# 7           0.05      Others                    NaN                    NaN
# 8           0.05      Others                    NaN                    NaN
# 9           0.05      Others                    NaN                    NaN
# 10          0.05      Others                    NaN                    NaN
# 11          0.05      Others                    NaN                    NaN
# 12          0.05      Others                    NaN                    NaN
# 13          0.05      Others                    NaN                    NaN
# 14          0.05      Others                    NaN                    NaN
# 15          0.05      Others                    NaN                    NaN
# 16          0.05      Others                    NaN                    NaN
# 17          0.05      Others                    NaN                    NaN
# 18          0.05      Others                    NaN                    NaN
# 19          0.05      Others                    NaN                    NaN
# 20          0.05      Others                    NaN                    NaN
# 21          0.05      Others                    NaN                    NaN
# 22          0.05      Others                    NaN                    NaN
# 23          0.05      Others                    NaN                    NaN
# 24          0.05      Others                    NaN                    NaN
#
#     Wording interactive 3 Wording interactive 4 Wording interactive 5  \
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# 5                     NaN                   NaN                   NaN
# 6                     NaN                   NaN                   NaN
# 7                     NaN                   NaN                   NaN
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# 13                    NaN                   NaN                   NaN
# 14                    NaN                   NaN                   NaN
# 15                    NaN                   NaN                   NaN
# 16                    NaN                   NaN                   NaN
# 17                    NaN                   NaN                   NaN
# 18                    NaN                   NaN                   NaN
# 19                    NaN                   NaN                   NaN
# 20                    NaN                   NaN                   NaN
# 21                    NaN                   NaN                   NaN
# 22                    NaN                   NaN                   NaN
# 23                    NaN                   NaN                   NaN
# 24                    NaN                   NaN                   NaN
#
#    Wording interactive 6 company_id
# 1                    NaN   QXNzb2Np
# 2                    NaN       QmVs
# 3                    NaN   RGFub25l
# 4                    NaN   RWNvdG9u
# 5                    NaN   RmVycmVy
# 6                    NaN   R2VuZXJh
# 7                    NaN   SGVybw==
# 8                    NaN   S2VsbG9n
# 9                    NaN   TWFycw==
# 10                   NaN   TW9uZGVs
# 11                   NaN   TmVzdGzD
# 12                   NaN   UGVwc2lj
# 13                   NaN   SGVua2Vs
# 14                   NaN       UCZH
# 15                   NaN   VW5pbGV2
# 16                   NaN   Q29sZ2F0
# 17                   NaN   Q290eQ==
# 18                   NaN   TCdPcsOp
# 19                   NaN   U2hpc2Vp
# 20                   NaN   QmVpZXJz
# 21                   NaN   Uy4gQy4g
# 22                   NaN   UmVja2l0
# 23                   NaN       R1NL
# 24                   NaN   Sm9obnNv
#
# [24 rows x 86 columns]

# %%
# Calculating global performance to choose pic

list_reference = ['Unrevealed', 'TotallyInsufficient', 'Sufficient', 'Partial', 'Strong', 'VeryStrong']

ref_dict = {}
for i, t in enumerate(list_reference):
    ref_dict[i+1] = t
    
global_score_reference_table = pd.DataFrame.from_dict(ref_dict, orient='index').reset_index().rename(columns={'index':'global_score',0:'global_score_label'})
global_score_reference_table['global_score'] = global_score_reference_table['global_score'].astype('str')
global_score_reference_table
# Out:
#   global_score   global_score_label
# 0            1           Unrevealed
# 1            2  TotallyInsufficient
# 2            3           Sufficient
# 3            4              Partial
# 4            5               Strong
# 5            6           VeryStrong

# %%
# Calculating score performance to choose color

list_reference2 = ['Non publiée', 'Vers + 4°C', 'Entre +2°C et +3°C', '2°C', 'Bien moins de 2°C', '1,5°C', 'n.a. (trop récente)']
list_hexcolors_direct = ['820000', 'C00000', 'FF8939', 'FEC800', '8CDF41', '0DB800', 'C00000']
list_scores = ['1','2','3','4','5','6','99']
    
direct_score_reference_table = pd.DataFrame(data={'direct_score': list_scores, 'direct_score_label': list_reference2, 'hexcolor':list_hexcolors_direct})

# %%
# Generating filtered df once company is selected

df_filtered = t1b4_data[t1b4_data['Sector']==secteur].copy()

for col in ['Global score', 'C1 direct score', 'C2 complete score']:
    df_filtered[col] = df_filtered[col].astype('int').astype('str')
    
# Filtering data & adding reference columns

df_filtered = df_filtered[['company_name','Global score','C1 direct score','C2 complete score']]
df_filtered = pd.merge(df_filtered, direct_score_reference_table, how='left', left_on='C1 direct score', right_on='direct_score').rename(columns={'direct_score_label':'c1_label', 'hexcolor': 'c1_color'}).drop(columns=['direct_score'])
df_filtered = pd.merge(df_filtered, direct_score_reference_table, how='left', left_on='C2 complete score', right_on='direct_score').rename(columns={'direct_score_label':'c2_label', 'hexcolor': 'c2_color'}).drop(columns=['direct_score'])
df_filtered = pd.merge(df_filtered, global_score_reference_table, how='left', left_on='Global score', right_on='global_score').drop(columns=['global_score'])

# Adding the global score image

df_filtered['global_score_pic'] = './assets/frames/climate_score/Frame_'+df_filtered['global_score_label']+'.png'

# %%
df_filtered
# Out:
#                         company_name Global score C1 direct score  \
# 0   Associated British Foods (alim.)            3               5
# 1                                Bel            4               3
# 2                             Danone            6               6
# 3                            Ecotone            5               6
# 4                            Ferrero            2               2
# 5                      General Mills            5               6
# 6                               Hero            4               3
# 7                            Kellogg            4               6
# 8                               Mars            4               6
# 9                           Mondelez            3               5
# 10                            Nestlé            4               6
# 11                           Pepsico            4               6
#
#    C2 complete score            c1_label c1_color             c2_label  \
# 0                  1   Bien moins de 2°C   8CDF41          Non publiée
# 1                  5  Entre +2°C et +3°C   FF8939    Bien moins de 2°C
# 2                  5               1,5°C   0DB800    Bien moins de 2°C
# 3                  1               1,5°C   0DB800          Non publiée
# 4                  2          Vers + 4°C   C00000           Vers + 4°C
# 5                  4               1,5°C   0DB800                  2°C
# 6                  1  Entre +2°C et +3°C   FF8939          Non publiée
# 7                  3               1,5°C   0DB800   Entre +2°C et +3°C
# 8                  3               1,5°C   0DB800   Entre +2°C et +3°C
# 9                 99   Bien moins de 2°C   8CDF41  n.a. (trop récente)
# 10                 3               1,5°C   0DB800   Entre +2°C et +3°C
# 11                 3               1,5°C   0DB800   Entre +2°C et +3°C
#
#    c2_color   global_score_label  \
# 0    820000           Sufficient
# 1    8CDF41              Partial
# 2    8CDF41           VeryStrong
# 3    820000               Strong
# 4    C00000  TotallyInsufficient
# 5    FEC800               Strong
# 6    820000              Partial
# 7    FF8939              Partial
# 8    FF8939              Partial
# 9    C00000           Sufficient
# 10   FF8939              Partial
# 11   FF8939              Partial
#
#                                      global_score_pic
# 0   ./assets/frames/climate_score/Frame_Sufficient...
# 1     ./assets/frames/climate_score/Frame_Partial.png
# 2   ./assets/frames/climate_score/Frame_VeryStrong...
# 3      ./assets/frames/climate_score/Frame_Strong.png
# 4   ./assets/frames/climate_score/Frame_TotallyIns...
# 5      ./assets/frames/climate_score/Frame_Strong.png
# 6     ./assets/frames/climate_score/Frame_Partial.png
# 7     ./assets/frames/climate_score/Frame_Partial.png
# 8     ./assets/frames/climate_score/Frame_Partial.png
# 9   ./assets/frames/climate_score/Frame_Sufficient...
# 10    ./assets/frames/climate_score/Frame_Partial.png
# 11    ./assets/frames/climate_score/Frame_Partial.png
